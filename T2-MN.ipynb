# %% [markdown]
# * Taller 2

# %% [markdown]
# activiades y al final ejercicio planteado

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# actividad profesor

# %%
# Out:
# f(300) = 26730299
# f(200.33482723778062) = 7920043.7774524735
# f(133.89213127865614) = 2346649.587675521
# f(89.59813646286764) = 695283.3745742877
# f(60.070526080061306) = 205996.2435379622
# f(40.3880672160149) = 61026.65276488316
# f(27.27042996010525) = 18075.61520069449
# f(18.5315213097551) = 5351.324355668195
# f(12.715260907923717) = 1582.4578534207833
# f(8.85317745609029) = 466.61791624982203
# f(6.303592249644243) = 136.57273960228153
# f(4.645839672970094) = 39.16935723759869
# f(3.6117045628978364) = 10.591029588242536
# f(3.038069273803689) = 2.3894435283260513
# f(2.809658737405398) = 0.3070701263695934
# f(2.770414513737685) = 0.008300775235135838
# f(2.7692932574717584) = 6.675968652114506e-06
# Raíz encontrada: 2.7692923542392167
# ...

# %%
# Extract x values from points
x_points = [point[0] for point in points]

# Plot the x points
plt.figure(figsize=(10, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# Ejercicio planteado

# %%
from scipy.optimize import newton

def f(x):
    y = x**3 - 3 * x**2 + x - 1
    print(f"f({x}) = {y}")
    return y
def f_prime(x):
    return 3 * x**2 - 6 * x + 1
estimations = []
def callback(x):
    estimations.append(x)

def newton_with_estimations(func, x0, fprime, tol=1e-6, maxiter=100):
    x = x0
    for _ in range(maxiter):
        callback(x)  
        fx = func(x)
        fpx = fprime(x)
        
        if abs(fpx) < 1e-10:
            raise RuntimeError("La derivadacero")
        
        x_new = x - fx / fpx
        if abs(x_new - x) < tol:
            callback(x_new)  
            return x_new
        x = x_new
    
    raise RuntimeError("No se encontró la raíz después de las iteraciones máximas")

# Estimación inicial
x0 = 100
root = newton_with_estimations(f, x0, f_prime)

print("Raíz encontrada:", root)
print("Estimaciones visitadas:", estimations)
# Out:
# f(100) = 970099
# f(67.00455766810653) = 287421.5546044976
# f(45.009926065596666) = 85151.64374336696
# f(30.35039723527028) = 25223.076156622286
# f(20.582860416480248) = 7468.634520318185
# f(14.079716839009599) = 2209.5053464848224
# f(9.757835905944379) = 652.2076251031732
# f(6.898518561069087) = 191.4272950525605
# f(5.028701696557697) = 55.330187134373084
# f(3.843680657951718) = 15.30811830079546
# f(3.1559707952275144) = 3.709463570275677
# f(2.8454158843448356) = 0.593842355835478
# f(2.773143092634202) = 0.0285402881796184
# f(2.7693029596247096) = 7.838698133211253e-05
# f(2.7692923543194023) = 5.96992677515118e-10
# Raíz encontrada: 2.7692923542386314
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**3 - 3 * x**2 + x - 1

x_values = np.linspace(-15, 15, 100)  
y_values = f(x_values)

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label=r"$f(x) = x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=1) 
plt.axvline(0, color="black", linewidth=1)  
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Funcion")
plt.legend()
plt.grid(True)
plt.show()
